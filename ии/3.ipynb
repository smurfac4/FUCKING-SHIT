# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D as pp
import numpy as np 
import random

# %%
def hh(i5,p2):
    h = 0 
    for i2 in range(len(p2)):
        if False == np.array_equal(p2[i2],i5):
            h+=1
        else:
            break
    if h == len(p2):
        return True 
    else:
        return False

fig = plt.figure()
ax = fig.add_subplot(111,projection = '3d')
o=[np.array([random.randint(0,10),random.randint(0,5),random.randint(0,5)]) for i in range(4)]
for i in o:
      ax.scatter(i[0],i[1],i[2])
plt.show()
p = []

for i in o:
    for i1 in o:
        if (False == np.array_equal(i,i1) and hh(i,p)==True and hh(i1,p)==True):
            print(np.linalg.norm(i-i1))
            print(np.linalg.norm(i-i1)**2)
            print(np.linalg.norm(i-i1,ord=np.inf))
            sm = (np.nonzero(i-i1))
            sm = np.shape(sm[0])[0] 
            print(sm)
    p.append(i)
plt.show()
# Out:
# 1.4142135623730951
# 2.0000000000000004
# 1.0
# 2
# 2.23606797749979
# 5.000000000000001
# 2.0
# 2
# 5.477225575051661
# 30.0
# 5.0
# 3
# 2.23606797749979
# 5.000000000000001
# 2.0
# 2
# 5.830951894845301
# 34.0
# 5.0
# 2
# 4.358898943540674
# 19.000000000000004
# 3.0
# 3
# [array([6, 4, 4]), array([6, 5, 3]), array([4, 5, 4])]

# %%
from sklearn.neighbors import KNeighborsClassifier
import numpy as np


# данные
X = np.array ([[-1,-1], [-2,-1], [-3,-2], [1, 1] , [2,1], [3,2]])
target = [0,0,0,1,1,1]


K =6
model = KNeighborsClassifier(n_neighbors = K)
model.fit(X, target)
print (model)

#делайем прогноз 
print ('(-2,-2) is class'),
print ( model.predict([[-2,-2]]))

print('(1,3) is class'),
print( model.predict([[1,3]]))
# Out:
# KNeighborsClassifier(n_neighbors=6)
# (-2,-2) is class
# [0]
# (1,3) is class
# [0]

# %%
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

iris =sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.figure(figsize=(16,7))

plt.subplot(121)
sns.scatterplot(data=iris,x ='petal_width',y='petal_length',hue = 'species',s = 70)
plt.xlabel('длина 2')
plt.ylabel('ширина 2')
plt.legend()
plt.grid()

plt.subplot(122)
sns.scatterplot(data=iris,x ='sepal_width',y='sepal_length',hue = 'species',s = 70)
plt.xlabel('длина 2')
plt.ylabel('ширина 2')
plt.legend()
plt.grid()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(iris.iloc[:, :-1],iris.iloc[:, -1],test_size = 0.15)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
X_train.head()
y_train.head()
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
y_pred
# Out:
# array(['versicolor', 'versicolor', 'virginica', 'virginica', 'versicolor',
#        'setosa', 'versicolor', 'virginica', 'versicolor', 'virginica',
#        'setosa', 'setosa', 'setosa', 'setosa', 'virginica', 'setosa',
#        'virginica', 'setosa', 'versicolor', 'setosa', 'setosa',
#        'versicolor', 'setosa'], dtype=object)

# %%
plt.figure(figsize=(10, 7))
sns.scatterplot(x='petal_width', y='petal_length', data=iris, hue='species', s=70)
plt.xlabel("Длина лепестка, см")
plt.ylabel("Ширина лепестка, см")
plt.legend(loc=2)
plt.grid()
for i in range(len(y_test)):
    if np.array(y_test)[i] != y_pred[i]: # то подсвечиваем точку красным
        plt.scatter(X_test.iloc[i, 3], X_test.iloc[i, 2], color='red', s=150)
print(f'accuracy: {accuracy_score(y_test, y_pred) :.3}')
# Out:
# accuracy: 0.913

# %%
from sklearn.feature_extraction import DictVectorizer
import pandas as pd

# %%
data ={'cиние':0,'карие':1,'черные':2,'зеленые':3,'cерые':4}
dict = DictVectorizer(sparse=False)
feat = dict.fit_transform(data)
feat
# Out:
# array([[4., 0., 3., 1., 2.]])
